# %% [markdown]
# # Deep Q learning with Doom 🕹️
# In this notebook we'll implement an agent <b>that plays Doom by using a Deep Q learning architecture.</b> <br>
# Our agent playing Doom:
#
# <img src="assets/doom.gif" style="max-width: 600px;" alt="Deep Q learning with Doom"/>

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
# %pip install tensorflow
# %pip install vizdoom
# %pip install scikit-image

import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment

import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.4.12)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/krimssmirk/Library/Python/3.11/lib/python/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/krimssmirk/Library/Python/3.11/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.54.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-image in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: scipy>=1.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (2.31.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in /Users/krimssmirk/Library/Python/3.11/lib/python/site-packages (from scikit-image) (22.0)
# Requirement already satisfied: lazy_loader>=0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image) (0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to < a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="assets/doom.png" style="max-width:500px;" alt="Doom"/>
#
# - A monster is spawned **randomly somewhere along the opposite wall**.
# - Player can only go **left/right and shoot**.
# - 1 hit is enough **to kill the monster**.
# - Episode finishes when **monster is killed or on timeout (300)**.
# <br><br>
# REWARDS:
#
# - +100 for killing the monster
# - -5 for missing
# - Episode ends after killing the monster or on timeout.
# - living reward = -1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()

    # Load the correct configuration
    game.load_config("basic.cfg")

    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("basic.wad")

    game.init()

    # Here our possible actions
    left = [1, 0, 0]
    right = [0, 1, 0]
    shoot = [0, 0, 1]
    possible_actions = [left, right, shoot]

    return game, possible_actions

"""
Here we performing random action to test the environment
"""
def test_environment():
    game = DoomGame()
    game.load_config("basic.cfg")
    game.set_doom_scenario_path("basic.wad")
    game.init()
    shoot = [0, 0, 1]
    left = [1, 0, 0]
    right = [0, 1, 0]
    actions = [shoot, left, right]

    episodes = 1
    for i in range(episodes):
        game.new_episode()
        while not game.is_episode_finished():
            state = game.get_state()
            img = state.screen_buffer
            misc = state.game_variables
            action = random.choice(actions)
            print(action, end=' ')
            reward = game.make_action(action)
            print ("reward:", reward)
            time.sleep(0.02)
        print ("Result:", game.get_total_reward())
        time.sleep(2)
    game.close()

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|

        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.

    return preprocessed_frame

    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)

    # Crop the screen (remove the roof because it contains no information)
    cropped_frame = frame[30:-10,30:-30]

    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0

    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [84,84])

    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how stack works:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((84,84), dtype=np.int) for i in range(stack_size)], maxlen=4)

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)

    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((84,84), dtype=np.int) for i in range(stack_size)], maxlen=4)

        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)

        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2)

    return stacked_state, stacked_frames

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### MODEL HYPERPARAMETERS
state_size = [84,84,4]      # Our input is a stack of 4 frames hence 84x84x4 (Width, height, channels)
action_size = game.get_available_buttons_size()              # 3 possible actions: left, right, shoot
learning_rate =  0.0002      # Alpha (aka learning rate)

### TRAINING HYPERPARAMETERS
total_episodes = 500        # Total episodes for training
max_steps = 100              # Max possible steps in an episode
batch_size = 64

# Exploration parameters for epsilon greedy strategy
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Q learning hyperparameters
gamma = 0.95               # Discounting rate

### MEMORY HYPERPARAMETERS
pretrain_length = batch_size   # Number of experiences stored in the Memory when initialized for the first time
memory_size = 1000000          # Number of experiences the Memory can keep

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = True

## TURN THIS TO TRUE IF YOU WANT TO RENDER THE ENVIRONMENT
episode_render = False

# %% [markdown]
# ## Step 5: Create our Deep Q-learning Neural Network model 🧠
# <img src="assets/model.png" alt="Model" />
# This is our Deep Q-learning model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a Q value for each actions

# %%
class DQNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='DQNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate

        with tf.compat.v1.variable_scope(name):
            # We create the placeholders
            # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
            # [None, 84, 84, 4]
            self.inputs_ = tf.compat.v1.placeholder(tf.float32, [None, *state_size], name="inputs")
            self.actions_ = tf.compat.v1.placeholder(tf.float32, [None, 3], name="actions_")

            # Remember that target_Q is the R(s,a) + ymax Qhat(s', a')
            self.target_Q = tf.compat.v1.placeholder(tf.float32, [None], name="target")

            """
            First convnet:
            CNN
            BatchNormalization
            ELU
            """
            # Input is 84x84x4
            self.conv1 = tf.compat.v1.layers.conv2d(inputs = self.inputs_,
                                         filters = 32,
                                         kernel_size = [8,8],
                                         strides = [4,4],
                                         padding = "VALID",
                                          kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                         name = "conv1")

            self.conv1_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv1,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm1')

            self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")
            ## --> [20, 20, 32]


            """
            Second convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv2 = tf.compat.v1.layers.conv2d(inputs = self.conv1_out,
                                 filters = 64,
                                 kernel_size = [4,4],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv2")

            self.conv2_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv2,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm2')

            self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
            ## --> [9, 9, 64]


            """
            Third convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv3 = tf.compat.v1.layers.conv2d(inputs = self.conv2_out,
                                 filters = 128,
                                 kernel_size = [4,4],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv3")

            self.conv3_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv3,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm3')

            self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
            ## --> [3, 3, 128]


            self.flatten = tf.compat.v1.layers.flatten(self.conv3_out)
            ## --> [1152]


            self.fc = tf.compat.v1.layers.dense(inputs = self.flatten,
                                  units = 1152,
                                  activation = tf.nn.elu,
                                       kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                name="fc1")


            self.output = tf.compat.v1.layers.dense(inputs = self.fc,
                                           kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                          units = 3,
                                        activation=None)


            # Q is our predicted Q value.
            self.Q = tf.reduce_sum(tf.multiply(self.output, self.actions_), axis=1)


            # The loss is the difference between our predicted Q_values and the Q_target
            # Sum(Qtarget - Q)^2
            self.loss = tf.reduce_mean(tf.square(self.target_Q - self.Q))

            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
tf.compat.v1.disable_eager_execution()

# %%
# Reset the graph
tf.compat.v1.reset_default_graph()

# Instantiate the DQNetwork
DQNetwork = DQNetwork(state_size, action_size, learning_rate)

# %% [markdown]
# ## Step 6: Experience Replay 🔁
# Now that we create our Neural Network, **we need to implement the Experience Replay method.** <br><br>
# Here we'll create the Memory object that creates a deque.A deque (double ended queue) is a data type that **removes the oldest element each time that you add a new element.**
#
# This part was taken from Udacity : <a href="https://github.com/udacity/deep-learning/blob/master/reinforcement/Q-learning-cart.ipynb" Cartpole DQN</a>

# %%
class Memory():
    def __init__(self, max_size):
        self.buffer = deque(maxlen = max_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        buffer_size = len(self.buffer)
        index = np.random.choice(np.arange(buffer_size),
                                size = batch_size,
                                replace = False)

        return [self.buffer[i] for i in index]

# %% [markdown]
# Here we'll **deal with the empty memory problem**: we pre-populate our memory by taking random actions and storing the experience (state, action, reward, new_state).

# %%
# Instantiate memory
memory = Memory(max_size = memory_size)

# Render the environment
game.new_episode()

for i in range(pretrain_length):
    # If it's the first step
    if i == 0:
        # First we need a state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    # Random action
    action = random.choice(possible_actions)

    # Get the rewards
    reward = game.make_action(action)

    # Look if the episode is finished
    done = game.is_episode_finished()

    # If we're dead
    if done:
        # We finished the episode
        next_state = np.zeros(state.shape)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Start a new episode
        game.new_episode()

        # First we need a state
        state = game.get_state().screen_buffer

        # Stack the frames
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    else:
        # Get the next state
        next_state = game.get_state().screen_buffer
        next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Our state is now the next_state
        state = next_state

# %% [markdown]
# ## Step 7: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=/tensorboard/dqn/1`

# %%
# Setup TensorBoard Writer
writer = tf.compat.v1.summary.FileWriter("./tensorboard/dqn/1")

## Losses
tf.compat.v1.summary.scalar("Loss", DQNetwork.loss)

write_op = tf.compat.v1.summary.merge_all()

# %% [markdown]
# ## Step 8: Train our Agent 🏃‍♂️
#
# Our algorithm:
# <br>
# * Initialize the weights
# * Init the environment
# * Initialize the decay rate (that will use to reduce epsilon)
# <br><br>
# * **For** episode to max_episode **do**
#     * Make new episode
#     * Set step to 0
#     * Observe the first state $s_0$
#     <br><br>
#     * **While** step < max_steps **do**:
#         * Increase decay_rate
#         * With $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s_t,a)$
#         * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#         * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#         * Sample random mini-batch from $D$: $<s, a, r, s'>$
#         * Set $\hat{Q} = r$ if the episode ends at $+1$, otherwise set $\hat{Q} = r + \gamma \max_{a'}{Q(s', a')}$
#         * Make a gradient descent step with loss $(\hat{Q} - Q(s, a))^2$
#     * **endfor**
#     <br><br>
# * **endfor**

# %%
"""
This function will do the part
With Ïµ select a random action atat, otherwise select at=argmaxaQ(st,a)
"""
def predict_action(explore_start, explore_stop, decay_rate, decay_step, state, actions):
    ## EPSILON GREEDY STRATEGY
    # Choose action a from state s using epsilon greedy.
    ## First we randomize a number
    exp_exp_tradeoff = np.random.rand()

    # Here we'll use an improved version of our epsilon greedy strategy used in Q-learning notebook
    explore_probability = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * decay_step)

    if (explore_probability > exp_exp_tradeoff):
        # Make a random action (exploration)
        action = random.choice(possible_actions)

    else:
        # Get action from Q-network (exploitation)
        # Estimate the Qs values state
        Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

        # Take the biggest Q value (= the best action)
        choice = np.argmax(Qs)
        action = possible_actions[int(choice)]

    return action, explore_probability

# %%
# Saver will help us to save our model
saver = tf.compat.v1.train.Saver()

if training == True:
    with tf.compat.v1.Session() as sess:
        # Initialize the variables
        sess.run(tf.compat.v1.global_variables_initializer())

        # Initialize the decay rate (that will use to reduce epsilon)
        decay_step = 0

        # Init the game
        game.init()

        for episode in range(total_episodes):
            # Set step to 0
            step = 0

            # Initialize the rewards of the episode
            episode_rewards = []

            # Make a new episode and observe the first state
            game.new_episode()
            state = game.get_state().screen_buffer

            # Remember that stack frame function also call our preprocess function.
            state, stacked_frames = stack_frames(stacked_frames, state, True)

            while step < max_steps:
                step += 1

                # Increase decay_step
                decay_step +=1

                # Predict the action to take and take it
                action, explore_probability = predict_action(explore_start, explore_stop, decay_rate, decay_step, state, possible_actions)

                # Do the action
                reward = game.make_action(action)

                # Look if the episode is finished
                done = game.is_episode_finished()

                # Add the reward to total reward
                episode_rewards.append(reward)

                # If the game is finished
                if done:
                    # the episode ends so no next state
                    next_state = np.zeros((84,84), dtype=np.int)
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

                    # Set step = max_steps to end the episode
                    step = max_steps

                    # Get the total reward of the episode
                    total_reward = np.sum(episode_rewards)

                    print('Episode: {}'.format(episode),
                              'Total reward: {}'.format(total_reward),
                              'Training loss: {:.4f}'.format(loss),
                              'Explore P: {:.4f}'.format(explore_probability))

                    memory.add((state, action, reward, next_state, done))

                else:
                    # Get the next state
                    next_state = game.get_state().screen_buffer

                    # Stack the frame of the next_state
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)


                    # Add experience to memory
                    memory.add((state, action, reward, next_state, done))

                    # st+1 is now our current state
                    state = next_state


                ### LEARNING PART
                # Obtain random mini-batch from memory
                batch = memory.sample(batch_size)
                states_mb = np.array([each[0] for each in batch], ndmin=3)
                actions_mb = np.array([each[1] for each in batch])
                rewards_mb = np.array([each[2] for each in batch])
                next_states_mb = np.array([each[3] for each in batch], ndmin=3)
                dones_mb = np.array([each[4] for each in batch])

                target_Qs_batch = []

                 # Get Q values for next_state
                Qs_next_state = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: next_states_mb})

                # Set Q_target = r if the episode ends at s+1, otherwise set Q_target = r + gamma*maxQ(s', a')
                for i in range(0, len(batch)):
                    terminal = dones_mb[i]

                    # If we are in a terminal state, only equals reward
                    if terminal:
                        target_Qs_batch.append(rewards_mb[i])

                    else:
                        target = rewards_mb[i] + gamma * np.max(Qs_next_state[i])
                        target_Qs_batch.append(target)


                targets_mb = np.array([each for each in target_Qs_batch])

                loss, _ = sess.run([DQNetwork.loss, DQNetwork.optimizer],
                                    feed_dict={DQNetwork.inputs_: states_mb,
                                               DQNetwork.target_Q: targets_mb,
                                               DQNetwork.actions_: actions_mb})

                # Write TF Summaries
                summary = sess.run(write_op, feed_dict={DQNetwork.inputs_: states_mb,
                                                   DQNetwork.target_Q: targets_mb,
                                                   DQNetwork.actions_: actions_mb})
                writer.add_summary(summary, episode)
                writer.flush()

            # Save model every 5 episodes
            if episode % 5 == 0:
                save_path = saver.save(sess, "./models/model.ckpt")
                print("Model Saved")
# Out:
# Episode: 0 Total reward: 93.0 Training loss: 164.0691 Explore P: 0.9992
# Model Saved
# Episode: 2 Total reward: 95.0 Training loss: 4.2862 Explore P: 0.9888
# Episode: 4 Total reward: 3.0 Training loss: 6.2360 Explore P: 0.9715
# Model Saved
# Episode: 7 Total reward: 67.0 Training loss: 3.9782 Explore P: 0.9497
# Episode: 8 Total reward: -2.0 Training loss: 18.8589 Explore P: 0.9420
# Episode: 10 Total reward: 38.0 Training loss: 5.5084 Explore P: 0.9278
# Model Saved
# Episode: 13 Total reward: 1.0 Training loss: 5.5935 Explore P: 0.9025
# Episode: 14 Total reward: 95.0 Training loss: 1.6744 Explore P: 0.9019
# Model Saved
# Episode: 17 Total reward: 92.0 Training loss: 3.7799 Explore P: 0.8835
# Episode: 19 Total reward: -1.0 Training loss: 3.4115 Explore P: 0.8677
# Model Saved
# Episode: 22 Total reward: 17.0 Training loss: 3.1154 Explore P: 0.8450
# Episode: 23 Total reward: 93.0 Training loss: 7.5967 Explore P: 0.8443
# Episode: 25 Total reward: 45.0 Training loss: 3.2229 Explore P: 0.8322
# Model Saved
# Episode: 26 Total reward: 49.0 Training loss: 4.3577 Explore P: 0.8288
# Episode: 30 Total reward: 44.0 Training loss: 3.4331 Explore P: 0.8008
# Model Saved
# Episode: 31 Total reward: 94.0 Training loss: 2.3316 Explore P: 0.8003
# Episode: 32 Total reward: 90.0 Training loss: 2.5862 Explore P: 0.7994
# Episode: 33 Total reward: 67.0 Training loss: 6.4238 Explore P: 0.7971
# Episode: 35 Total reward: -24.0 Training loss: 2.1410 Explore P: 0.7816
# Model Saved
# Episode: 36 Total reward: 5.0 Training loss: 3.9917 Explore P: 0.7757
# Episode: 37 Total reward: 48.0 Training loss: 6.5496 Explore P: 0.7724
# Episode: 38 Total reward: 58.0 Training loss: 4.4399 Explore P: 0.7695
# Model Saved
# Episode: 42 Total reward: 88.0 Training loss: 3.9278 Explore P: 0.7461
# Episode: 43 Total reward: 94.0 Training loss: 2.7809 Explore P: 0.7456
# Episode: 44 Total reward: 49.0 Training loss: 3.7861 Explore P: 0.7425
# Episode: 45 Total reward: 26.0 Training loss: 27.5032 Explore P: 0.7381
# Model Saved
# Episode: 46 Total reward: 67.0 Training loss: 16.1589 Explore P: 0.7360
# Episode: 48 Total reward: 95.0 Training loss: 3.0125 Explore P: 0.7284
# Episode: 50 Total reward: 39.0 Training loss: 3.1339 Explore P: 0.7175
# Model Saved
# Episode: 53 Total reward: 64.0 Training loss: 5.5365 Explore P: 0.7013
# Model Saved
# Episode: 56 Total reward: 47.0 Training loss: 2.7629 Explore P: 0.6847
# Episode: 57 Total reward: 4.0 Training loss: 6.5209 Explore P: 0.6795
# Episode: 60 Total reward: 46.0 Training loss: 2.2321 Explore P: 0.6633
# Model Saved
# Episode: 61 Total reward: 93.0 Training loss: 6.3187 Explore P: 0.6628
# Episode: 64 Total reward: 75.0 Training loss: 1.3382 Explore P: 0.6485
# Episode: 65 Total reward: 59.0 Training loss: 5.5476 Explore P: 0.6461
# Model Saved
# Episode: 66 Total reward: 44.0 Training loss: 4.2658 Explore P: 0.6431
# Episode: 67 Total reward: 87.0 Training loss: 4.6386 Explore P: 0.6423
# Episode: 68 Total reward: 95.0 Training loss: 3.4310 Explore P: 0.6419
# Episode: 69 Total reward: 46.0 Training loss: 9.1214 Explore P: 0.6390
# Episode: 70 Total reward: 90.0 Training loss: 5.7252 Explore P: 0.6384
# Model Saved
# Episode: 71 Total reward: 71.0 Training loss: 3.7190 Explore P: 0.6368
# Episode: 73 Total reward: -9.0 Training loss: 5.5135 Explore P: 0.6250
# Episode: 74 Total reward: 46.0 Training loss: 5.1890 Explore P: 0.6222
# Episode: 75 Total reward: 30.0 Training loss: 5.9012 Explore P: 0.6185
# Model Saved
# Episode: 76 Total reward: 8.0 Training loss: 8.1198 Explore P: 0.6141
# Episode: 77 Total reward: 50.0 Training loss: 7.9828 Explore P: 0.6116
# Episode: 78 Total reward: 5.0 Training loss: 2.2440 Explore P: 0.6071
# Episode: 79 Total reward: 15.0 Training loss: 4.7310 Explore P: 0.6028
# Episode: 80 Total reward: 67.0 Training loss: 5.2314 Explore P: 0.6011
# Model Saved
# Episode: 82 Total reward: -7.0 Training loss: 5.0191 Explore P: 0.5901
# Episode: 85 Total reward: 64.0 Training loss: 3.5180 Explore P: 0.5768
# Model Saved
# Episode: 86 Total reward: 13.0 Training loss: 7.8060 Explore P: 0.5727
# Episode: 87 Total reward: 88.0 Training loss: 9.3044 Explore P: 0.5719
# Episode: 88 Total reward: 26.0 Training loss: 11.6788 Explore P: 0.5683
# Model Saved
# Episode: 91 Total reward: 65.0 Training loss: 13.5389 Explore P: 0.5556
# Episode: 92 Total reward: 75.0 Training loss: 6.6459 Explore P: 0.5544
# Episode: 93 Total reward: 49.0 Training loss: 4.7324 Explore P: 0.5521
# Episode: 95 Total reward: 69.0 Training loss: 6.1103 Explore P: 0.5453
# Model Saved
# Episode: 96 Total reward: 88.0 Training loss: 5.5621 Explore P: 0.5446
# Episode: 97 Total reward: 66.0 Training loss: 4.1928 Explore P: 0.5430
# Episode: 98 Total reward: 35.0 Training loss: 5.6740 Explore P: 0.5400
# Episode: 99 Total reward: 39.0 Training loss: 4.3348 Explore P: 0.5373
# Episode: 100 Total reward: 69.0 Training loss: 3.9375 Explore P: 0.5358
# Model Saved
# Episode: 101 Total reward: 67.0 Training loss: 8.2374 Explore P: 0.5343
# Episode: 102 Total reward: 45.0 Training loss: 10.2487 Explore P: 0.5319
# Episode: 103 Total reward: 28.0 Training loss: 4.5007 Explore P: 0.5286
# Episode: 104 Total reward: 10.0 Training loss: 7.6814 Explore P: 0.5250
# Episode: 105 Total reward: 91.0 Training loss: 2.4308 Explore P: 0.5245
# Model Saved
# Episode: 106 Total reward: -12.0 Training loss: 9.3496 Explore P: 0.5197
# Episode: 107 Total reward: 51.0 Training loss: 6.5169 Explore P: 0.5177
# Episode: 108 Total reward: 48.0 Training loss: 13.2279 Explore P: 0.5155
# Episode: 109 Total reward: 42.0 Training loss: 4.0903 Explore P: 0.5130
# Episode: 110 Total reward: 38.0 Training loss: 4.1432 Explore P: 0.5103
# Model Saved
# Episode: 111 Total reward: 45.0 Training loss: 11.3592 Explore P: 0.5081
# Episode: 112 Total reward: 40.0 Training loss: 12.5584 Explore P: 0.5055
# Episode: 113 Total reward: 91.0 Training loss: 7.8354 Explore P: 0.5050
# Episode: 114 Total reward: 24.0 Training loss: 9.3355 Explore P: 0.5020
# Episode: 115 Total reward: 55.0 Training loss: 10.6267 Explore P: 0.5002
# Model Saved
# Episode: 116 Total reward: 32.0 Training loss: 6.3835 Explore P: 0.4976
# Episode: 117 Total reward: 63.0 Training loss: 6.8395 Explore P: 0.4959
# Episode: 118 Total reward: 26.0 Training loss: 3.9204 Explore P: 0.4930
# Episode: 119 Total reward: 50.0 Training loss: 3.9186 Explore P: 0.4911
# Episode: 120 Total reward: 66.0 Training loss: 8.1703 Explore P: 0.4896
# Model Saved
# Episode: 121 Total reward: 37.0 Training loss: 4.3653 Explore P: 0.4870
# Episode: 122 Total reward: 69.0 Training loss: 18.2418 Explore P: 0.4858
# Episode: 123 Total reward: 63.0 Training loss: 10.9594 Explore P: 0.4842
# Episode: 124 Total reward: 47.0 Training loss: 4.9722 Explore P: 0.4819
# Episode: 125 Total reward: 95.0 Training loss: 36.4663 Explore P: 0.4816
# Model Saved
# Episode: 126 Total reward: 95.0 Training loss: 5.3714 Explore P: 0.4813
# Episode: 127 Total reward: 18.0 Training loss: 5.0890 Explore P: 0.4781
# Episode: 128 Total reward: 66.0 Training loss: 5.4834 Explore P: 0.4767
# Episode: 129 Total reward: 58.0 Training loss: 3.0499 Explore P: 0.4749
# Episode: 130 Total reward: 17.0 Training loss: 4.7877 Explore P: 0.4717
# Model Saved
# Episode: 131 Total reward: 69.0 Training loss: 6.7974 Explore P: 0.4705
# Episode: 132 Total reward: 26.0 Training loss: 2.4482 Explore P: 0.4677
# Episode: 133 Total reward: 52.0 Training loss: 6.3309 Explore P: 0.4657
# Episode: 134 Total reward: 68.0 Training loss: 21.0034 Explore P: 0.4645
# Episode: 135 Total reward: 87.0 Training loss: 5.5730 Explore P: 0.4638
# Model Saved
# Episode: 137 Total reward: 36.0 Training loss: 4.2981 Explore P: 0.4568
# Episode: 138 Total reward: 51.0 Training loss: 3.2855 Explore P: 0.4548
# Episode: 139 Total reward: 71.0 Training loss: 5.9278 Explore P: 0.4537
# Episode: 140 Total reward: 74.0 Training loss: 4.5178 Explore P: 0.4527
# Model Saved
# Episode: 141 Total reward: 33.0 Training loss: 11.0769 Explore P: 0.4502
# Episode: 142 Total reward: 83.0 Training loss: 6.4017 Explore P: 0.4494
# Episode: 143 Total reward: 43.0 Training loss: 2.7561 Explore P: 0.4473
# Episode: 144 Total reward: 35.0 Training loss: 5.0801 Explore P: 0.4449
# Episode: 145 Total reward: 50.0 Training loss: 5.1820 Explore P: 0.4431
# Model Saved
# Episode: 146 Total reward: 88.0 Training loss: 7.1893 Explore P: 0.4425
# Episode: 147 Total reward: 64.0 Training loss: 5.5668 Explore P: 0.4411
# Episode: 148 Total reward: 39.0 Training loss: 5.5484 Explore P: 0.4389
# Episode: 149 Total reward: 66.0 Training loss: 6.4340 Explore P: 0.4376
# Episode: 150 Total reward: 64.0 Training loss: 6.0279 Explore P: 0.4362
# Model Saved
# Episode: 152 Total reward: 48.0 Training loss: 6.5399 Explore P: 0.4302
# Episode: 153 Total reward: 94.0 Training loss: 6.4632 Explore P: 0.4299
# Episode: 154 Total reward: 67.0 Training loss: 8.0166 Explore P: 0.4285
# Episode: 155 Total reward: 65.0 Training loss: 5.8119 Explore P: 0.4272
# Model Saved
# Episode: 156 Total reward: 15.0 Training loss: 13.0289 Explore P: 0.4242
# Episode: 157 Total reward: 57.0 Training loss: 3.9032 Explore P: 0.4226
# Episode: 158 Total reward: 64.0 Training loss: 8.5627 Explore P: 0.4213
# Episode: 159 Total reward: 69.0 Training loss: 7.1797 Explore P: 0.4202
# Episode: 160 Total reward: 43.0 Training loss: 7.2503 Explore P: 0.4182
# Model Saved
# Episode: 161 Total reward: 53.0 Training loss: 5.5673 Explore P: 0.4167
# Episode: 163 Total reward: 65.0 Training loss: 5.0218 Explore P: 0.4114
# Episode: 165 Total reward: 41.0 Training loss: 4.7220 Explore P: 0.4054
# Model Saved
# Episode: 166 Total reward: 64.0 Training loss: 6.5399 Explore P: 0.4041
# Episode: 167 Total reward: 69.0 Training loss: 16.4220 Explore P: 0.4031
# Episode: 168 Total reward: 57.0 Training loss: 3.0313 Explore P: 0.4015
# Episode: 169 Total reward: 41.0 Training loss: 9.4837 Explore P: 0.3996
# Episode: 170 Total reward: 50.0 Training loss: 5.5943 Explore P: 0.3980
# Model Saved
# Episode: 171 Total reward: 85.0 Training loss: 7.1157 Explore P: 0.3974
# Episode: 173 Total reward: 76.0 Training loss: 4.3140 Explore P: 0.3928
# Episode: 174 Total reward: 45.0 Training loss: 5.3565 Explore P: 0.3910
# Episode: 175 Total reward: 61.0 Training loss: 7.2468 Explore P: 0.3897
# Model Saved
# Episode: 176 Total reward: 75.0 Training loss: 2.8392 Explore P: 0.3889
# Episode: 177 Total reward: 20.0 Training loss: 4.7619 Explore P: 0.3864
# Episode: 178 Total reward: 62.0 Training loss: 5.6543 Explore P: 0.3851
# Episode: 179 Total reward: 65.0 Training loss: 7.3892 Explore P: 0.3838
# Episode: 180 Total reward: 7.0 Training loss: 8.3460 Explore P: 0.3808
# Model Saved
# Episode: 181 Total reward: 70.0 Training loss: 5.7018 Explore P: 0.3799
# Episode: 182 Total reward: 60.0 Training loss: 7.1885 Explore P: 0.3785
# Episode: 183 Total reward: 47.0 Training loss: 19.3681 Explore P: 0.3767
# Episode: 184 Total reward: 60.0 Training loss: 8.4760 Explore P: 0.3754
# Episode: 185 Total reward: 63.0 Training loss: 5.6311 Explore P: 0.3742
# Model Saved
# Episode: 187 Total reward: 90.0 Training loss: 4.8157 Explore P: 0.3702
# Episode: 188 Total reward: 66.0 Training loss: 5.6934 Explore P: 0.3691
# Episode: 189 Total reward: 71.0 Training loss: 6.7626 Explore P: 0.3682
# Episode: 190 Total reward: 87.0 Training loss: 5.5956 Explore P: 0.3677
# Model Saved
# Episode: 191 Total reward: 57.0 Training loss: 6.5404 Explore P: 0.3665
# Episode: 192 Total reward: 92.0 Training loss: 7.0990 Explore P: 0.3662
# Episode: 193 Total reward: 46.0 Training loss: 6.9106 Explore P: 0.3646
# Episode: 194 Total reward: 80.0 Training loss: 3.5795 Explore P: 0.3638
# Episode: 195 Total reward: 68.0 Training loss: 6.2291 Explore P: 0.3628
# Model Saved
# Episode: 196 Total reward: 52.0 Training loss: 7.3376 Explore P: 0.3615
# Episode: 197 Total reward: 67.0 Training loss: 2.8768 Explore P: 0.3604
# Episode: 198 Total reward: 62.0 Training loss: 8.4976 Explore P: 0.3593
# Episode: 200 Total reward: 27.0 Training loss: 6.7374 Explore P: 0.3537
# Model Saved
# Episode: 201 Total reward: 71.0 Training loss: 5.6716 Explore P: 0.3529
# Episode: 202 Total reward: 64.0 Training loss: 8.8004 Explore P: 0.3518
# Episode: 203 Total reward: 15.0 Training loss: 8.3379 Explore P: 0.3492
# Episode: 205 Total reward: 45.0 Training loss: 7.8163 Explore P: 0.3443
# Model Saved
# Episode: 206 Total reward: 47.0 Training loss: 6.0363 Explore P: 0.3428
# Episode: 207 Total reward: 95.0 Training loss: 7.4210 Explore P: 0.3426
# Episode: 208 Total reward: 67.0 Training loss: 8.0872 Explore P: 0.3417
# Episode: 209 Total reward: 74.0 Training loss: 5.3298 Explore P: 0.3409
# Episode: 210 Total reward: 33.0 Training loss: 8.9190 Explore P: 0.3390
# Model Saved
# Episode: 211 Total reward: 75.0 Training loss: 4.9941 Explore P: 0.3383
# Episode: 212 Total reward: 63.0 Training loss: 4.8763 Explore P: 0.3372
# Episode: 213 Total reward: 19.0 Training loss: 5.5518 Explore P: 0.3351
# Episode: 214 Total reward: 57.0 Training loss: 6.8293 Explore P: 0.3338
# Episode: 215 Total reward: 68.0 Training loss: 13.7601 Explore P: 0.3329
# Model Saved
# Episode: 216 Total reward: 68.0 Training loss: 4.9089 Explore P: 0.3320
# Episode: 217 Total reward: 69.0 Training loss: 8.0504 Explore P: 0.3311
# Episode: 219 Total reward: 39.0 Training loss: 6.0016 Explore P: 0.3263
# Model Saved
# Episode: 221 Total reward: 49.0 Training loss: 8.6168 Explore P: 0.3218
# Episode: 222 Total reward: 67.0 Training loss: 7.9728 Explore P: 0.3209
# Episode: 223 Total reward: 52.0 Training loss: 7.4237 Explore P: 0.3197
# Episode: 224 Total reward: 63.0 Training loss: 4.4662 Explore P: 0.3187
# Episode: 225 Total reward: 94.0 Training loss: 7.2650 Explore P: 0.3185
# Model Saved
# Episode: 226 Total reward: 64.0 Training loss: 24.7536 Explore P: 0.3175
# Episode: 227 Total reward: 95.0 Training loss: 3.8169 Explore P: 0.3173
# Episode: 228 Total reward: 10.0 Training loss: 6.2146 Explore P: 0.3150
# Episode: 229 Total reward: 95.0 Training loss: 5.6718 Explore P: 0.3148
# Episode: 230 Total reward: 76.0 Training loss: 5.9763 Explore P: 0.3142
# Model Saved
# Episode: 231 Total reward: 93.0 Training loss: 5.1199 Explore P: 0.3139
# Episode: 232 Total reward: 49.0 Training loss: 8.0789 Explore P: 0.3127
# Episode: 233 Total reward: 62.0 Training loss: 4.9384 Explore P: 0.3116
# Episode: 234 Total reward: 40.0 Training loss: 5.8792 Explore P: 0.3101
# Episode: 235 Total reward: 63.0 Training loss: 6.2638 Explore P: 0.3091
# Model Saved
# Episode: 236 Total reward: 76.0 Training loss: 6.9395 Explore P: 0.3085
# Episode: 237 Total reward: 61.0 Training loss: 9.4506 Explore P: 0.3075
# Episode: 238 Total reward: 60.0 Training loss: 9.1425 Explore P: 0.3064
# Episode: 239 Total reward: 72.0 Training loss: 6.8689 Explore P: 0.3057
# Episode: 240 Total reward: 71.0 Training loss: 5.0037 Explore P: 0.3049
# Model Saved
# Episode: 241 Total reward: 73.0 Training loss: 5.9285 Explore P: 0.3043
# Episode: 242 Total reward: 45.0 Training loss: 7.1193 Explore P: 0.3029
# Episode: 243 Total reward: 49.0 Training loss: 7.6637 Explore P: 0.3017
# Episode: 245 Total reward: 41.0 Training loss: 5.4617 Explore P: 0.2974
# Model Saved
# Episode: 246 Total reward: 65.0 Training loss: 9.5722 Explore P: 0.2965
# Episode: 247 Total reward: 94.0 Training loss: 5.9112 Explore P: 0.2963
# Episode: 248 Total reward: 90.0 Training loss: 5.8458 Explore P: 0.2959
# Episode: 249 Total reward: 61.0 Training loss: 7.0510 Explore P: 0.2949
# Episode: 250 Total reward: 67.0 Training loss: 12.3951 Explore P: 0.2941
# Model Saved
# Episode: 251 Total reward: 69.0 Training loss: 4.3838 Explore P: 0.2934
# Episode: 252 Total reward: 51.0 Training loss: 4.0853 Explore P: 0.2922
# Episode: 253 Total reward: 38.0 Training loss: 3.0620 Explore P: 0.2907
# Episode: 254 Total reward: 50.0 Training loss: 3.4939 Explore P: 0.2896
# Episode: 255 Total reward: 65.0 Training loss: 9.4985 Explore P: 0.2887
# Model Saved
# Episode: 256 Total reward: 55.0 Training loss: 7.5309 Explore P: 0.2876
# Episode: 257 Total reward: 90.0 Training loss: 5.5909 Explore P: 0.2873
# Episode: 258 Total reward: 27.0 Training loss: 8.6614 Explore P: 0.2856
# Episode: 259 Total reward: 51.0 Training loss: 8.7820 Explore P: 0.2845
# Episode: 260 Total reward: 44.0 Training loss: 7.4163 Explore P: 0.2831
# Model Saved
# Episode: 261 Total reward: 61.0 Training loss: 6.2369 Explore P: 0.2822
# Episode: 262 Total reward: 74.0 Training loss: 8.8381 Explore P: 0.2816
# Episode: 263 Total reward: 30.0 Training loss: 3.9973 Explore P: 0.2799
# Episode: 264 Total reward: 34.0 Training loss: 7.1901 Explore P: 0.2784
# Episode: 265 Total reward: 68.0 Training loss: 9.8417 Explore P: 0.2776
# Model Saved
# Episode: 266 Total reward: 49.0 Training loss: 5.2969 Explore P: 0.2765
# Episode: 267 Total reward: 63.0 Training loss: 5.7913 Explore P: 0.2756
# Episode: 268 Total reward: 51.0 Training loss: 4.4040 Explore P: 0.2746
# Episode: 269 Total reward: 95.0 Training loss: 5.9538 Explore P: 0.2744
# Episode: 270 Total reward: 64.0 Training loss: 7.7033 Explore P: 0.2736
# Model Saved
# Episode: 271 Total reward: 52.0 Training loss: 6.8253 Explore P: 0.2724
# Episode: 272 Total reward: 90.0 Training loss: 6.7629 Explore P: 0.2721
# Episode: 273 Total reward: 40.0 Training loss: 6.3942 Explore P: 0.2708
# Episode: 274 Total reward: 66.0 Training loss: 12.7609 Explore P: 0.2700
# Episode: 275 Total reward: 95.0 Training loss: 4.4266 Explore P: 0.2699
# Model Saved
# Episode: 276 Total reward: 47.0 Training loss: 8.5500 Explore P: 0.2687
# Episode: 277 Total reward: 8.0 Training loss: 10.6523 Explore P: 0.2667
# Episode: 278 Total reward: 55.0 Training loss: 11.6138 Explore P: 0.2656
# Episode: 279 Total reward: 65.0 Training loss: 5.7630 Explore P: 0.2649
# Episode: 280 Total reward: 72.0 Training loss: 7.2298 Explore P: 0.2642
# Model Saved
# Episode: 281 Total reward: 85.0 Training loss: 4.2230 Explore P: 0.2638
# Episode: 282 Total reward: 27.0 Training loss: 9.6170 Explore P: 0.2623
# Episode: 283 Total reward: 10.0 Training loss: 4.0443 Explore P: 0.2606
# Episode: 284 Total reward: 59.0 Training loss: 10.3305 Explore P: 0.2596
# Episode: 285 Total reward: 45.0 Training loss: 5.2464 Explore P: 0.2584
# Model Saved
# Episode: 286 Total reward: 84.0 Training loss: 6.0697 Explore P: 0.2579
# Episode: 287 Total reward: 60.0 Training loss: 3.4584 Explore P: 0.2571
# Episode: 288 Total reward: 95.0 Training loss: 6.7723 Explore P: 0.2569
# Episode: 289 Total reward: 71.0 Training loss: 10.4931 Explore P: 0.2563
# Episode: 290 Total reward: 41.0 Training loss: 6.9970 Explore P: 0.2551
# Model Saved
# Episode: 291 Total reward: 93.0 Training loss: 9.2785 Explore P: 0.2549
# Episode: 292 Total reward: 80.0 Training loss: 5.5320 Explore P: 0.2544
# Episode: 295 Total reward: 85.0 Training loss: 4.9660 Explore P: 0.2491
# Model Saved
# Episode: 296 Total reward: 93.0 Training loss: 8.1529 Explore P: 0.2489
# Episode: 297 Total reward: 65.0 Training loss: 7.6167 Explore P: 0.2482
# Episode: 298 Total reward: 90.0 Training loss: 6.0518 Explore P: 0.2479
# Episode: 299 Total reward: 74.0 Training loss: 8.8083 Explore P: 0.2473
# Model Saved
# Episode: 301 Total reward: 70.0 Training loss: 8.2116 Explore P: 0.2443
# Episode: 302 Total reward: 93.0 Training loss: 6.1211 Explore P: 0.2441
# Episode: 303 Total reward: 32.0 Training loss: 3.9481 Explore P: 0.2428
# Episode: 304 Total reward: 95.0 Training loss: 6.2586 Explore P: 0.2426
# Model Saved
# Episode: 306 Total reward: 85.0 Training loss: 5.2209 Explore P: 0.2399
# Episode: 307 Total reward: 68.0 Training loss: 9.4549 Explore P: 0.2393
# Episode: 308 Total reward: 69.0 Training loss: 4.4263 Explore P: 0.2387
# Episode: 309 Total reward: 70.0 Training loss: 4.9097 Explore P: 0.2381
# Episode: 310 Total reward: 93.0 Training loss: 6.3632 Explore P: 0.2379
# Model Saved
# Episode: 311 Total reward: 72.0 Training loss: 4.4901 Explore P: 0.2374
# Episode: 312 Total reward: 76.0 Training loss: 9.8676 Explore P: 0.2369
# Episode: 313 Total reward: 95.0 Training loss: 14.1029 Explore P: 0.2368
# Episode: 314 Total reward: 75.0 Training loss: 7.4585 Explore P: 0.2363
# Episode: 315 Total reward: 55.0 Training loss: 9.2842 Explore P: 0.2354
# Model Saved
# Episode: 316 Total reward: 70.0 Training loss: 8.5627 Explore P: 0.2348
# Episode: 317 Total reward: 70.0 Training loss: 3.6522 Explore P: 0.2342
# Episode: 318 Total reward: 94.0 Training loss: 4.2736 Explore P: 0.2340
# Episode: 319 Total reward: 60.0 Training loss: 7.2148 Explore P: 0.2332
# Episode: 320 Total reward: 64.0 Training loss: 7.0292 Explore P: 0.2325
# Model Saved
# Episode: 321 Total reward: 87.0 Training loss: 7.0501 Explore P: 0.2322
# Episode: 322 Total reward: 71.0 Training loss: 7.0541 Explore P: 0.2317
# Episode: 323 Total reward: 53.0 Training loss: 2.2563 Explore P: 0.2308
# Episode: 324 Total reward: 38.0 Training loss: 4.8162 Explore P: 0.2298
# Episode: 325 Total reward: 69.0 Training loss: 4.7340 Explore P: 0.2292
# Model Saved
# Episode: 326 Total reward: 43.0 Training loss: 6.5577 Explore P: 0.2281
# Episode: 327 Total reward: 21.0 Training loss: 10.1181 Explore P: 0.2267
# Episode: 328 Total reward: 90.0 Training loss: 9.4462 Explore P: 0.2265
# Episode: 329 Total reward: 63.0 Training loss: 19.8914 Explore P: 0.2257
# Episode: 330 Total reward: 68.0 Training loss: 5.0745 Explore P: 0.2251
# Model Saved
# Episode: 331 Total reward: 63.0 Training loss: 6.3907 Explore P: 0.2244
# Episode: 332 Total reward: 43.0 Training loss: 7.5947 Explore P: 0.2234
# Episode: 333 Total reward: 70.0 Training loss: 5.1792 Explore P: 0.2229
# Episode: 334 Total reward: 95.0 Training loss: 9.0399 Explore P: 0.2227
# Episode: 335 Total reward: 95.0 Training loss: 5.8613 Explore P: 0.2226
# Model Saved
# Episode: 336 Total reward: 73.0 Training loss: 4.2049 Explore P: 0.2221
# Episode: 337 Total reward: 49.0 Training loss: 5.2871 Explore P: 0.2212
# Episode: 338 Total reward: 72.0 Training loss: 5.1683 Explore P: 0.2207
# Episode: 339 Total reward: 90.0 Training loss: 5.7077 Explore P: 0.2205
# Episode: 340 Total reward: 95.0 Training loss: 19.1266 Explore P: 0.2204
# Model Saved
# Episode: 341 Total reward: 64.0 Training loss: 5.6469 Explore P: 0.2197
# Episode: 342 Total reward: 42.0 Training loss: 4.0607 Explore P: 0.2187
# Episode: 343 Total reward: 73.0 Training loss: 7.3742 Explore P: 0.2182
# Episode: 344 Total reward: 71.0 Training loss: 10.0507 Explore P: 0.2177
# Episode: 345 Total reward: 66.0 Training loss: 3.6060 Explore P: 0.2170
# Model Saved
# Episode: 346 Total reward: 71.0 Training loss: 5.2454 Explore P: 0.2165
# Episode: 347 Total reward: 75.0 Training loss: 7.0971 Explore P: 0.2161
# Episode: 348 Total reward: 72.0 Training loss: 10.8364 Explore P: 0.2156
# Episode: 349 Total reward: 57.0 Training loss: 12.0709 Explore P: 0.2149
# Episode: 350 Total reward: 56.0 Training loss: 6.8104 Explore P: 0.2141
# Model Saved
# Episode: 351 Total reward: 83.0 Training loss: 10.0098 Explore P: 0.2137
# Episode: 352 Total reward: 88.0 Training loss: 4.7062 Explore P: 0.2134
# Episode: 353 Total reward: 69.0 Training loss: 7.8755 Explore P: 0.2129
# Episode: 354 Total reward: 91.0 Training loss: 12.6986 Explore P: 0.2127
# Episode: 355 Total reward: 94.0 Training loss: 9.9318 Explore P: 0.2126
# Model Saved
# Episode: 356 Total reward: 95.0 Training loss: 6.5312 Explore P: 0.2124
# Episode: 357 Total reward: 86.0 Training loss: 10.7893 Explore P: 0.2121
# Episode: 358 Total reward: 60.0 Training loss: 7.0417 Explore P: 0.2114
# Episode: 359 Total reward: 68.0 Training loss: 6.8137 Explore P: 0.2108
# Episode: 360 Total reward: 68.0 Training loss: 5.8840 Explore P: 0.2103
# Model Saved
# Episode: 361 Total reward: 91.0 Training loss: 10.2110 Explore P: 0.2101
# Episode: 362 Total reward: 14.0 Training loss: 3.9171 Explore P: 0.2086
# Episode: 363 Total reward: 95.0 Training loss: 8.6568 Explore P: 0.2085
# Episode: 364 Total reward: 95.0 Training loss: 4.9907 Explore P: 0.2084
# Episode: 365 Total reward: 55.0 Training loss: 5.7796 Explore P: 0.2076
# Model Saved
# Episode: 366 Total reward: 30.0 Training loss: 6.6020 Explore P: 0.2065
# Episode: 367 Total reward: 93.0 Training loss: 4.4307 Explore P: 0.2063
# Episode: 368 Total reward: 64.0 Training loss: 4.8790 Explore P: 0.2057
# Episode: 369 Total reward: 69.0 Training loss: 5.4519 Explore P: 0.2052
# Episode: 370 Total reward: 95.0 Training loss: 8.7238 Explore P: 0.2051
# Model Saved
# Episode: 371 Total reward: 72.0 Training loss: 6.0781 Explore P: 0.2046
# Episode: 372 Total reward: 50.0 Training loss: 4.8987 Explore P: 0.2037
# Episode: 373 Total reward: 48.0 Training loss: 13.1905 Explore P: 0.2029
# Episode: 374 Total reward: 86.0 Training loss: 6.7472 Explore P: 0.2026
# Episode: 375 Total reward: 44.0 Training loss: 7.6053 Explore P: 0.2017
# Model Saved
# Episode: 376 Total reward: 63.0 Training loss: 8.5620 Explore P: 0.2010
# Episode: 377 Total reward: 68.0 Training loss: 12.9452 Explore P: 0.2005
# Episode: 378 Total reward: 42.0 Training loss: 4.7120 Explore P: 0.1996
# Episode: 379 Total reward: 91.0 Training loss: 6.7079 Explore P: 0.1994
# Episode: 380 Total reward: 86.0 Training loss: 3.8673 Explore P: 0.1991
# Model Saved
# Episode: 381 Total reward: 66.0 Training loss: 10.6284 Explore P: 0.1985
# Episode: 382 Total reward: 95.0 Training loss: 8.6130 Explore P: 0.1984
# Episode: 383 Total reward: 75.0 Training loss: 3.6404 Explore P: 0.1980
# Episode: 384 Total reward: 73.0 Training loss: 3.8342 Explore P: 0.1976
# Episode: 385 Total reward: 70.0 Training loss: 4.2333 Explore P: 0.1971
# Model Saved
# Episode: 386 Total reward: 40.0 Training loss: 7.3284 Explore P: 0.1962
# Episode: 387 Total reward: 85.0 Training loss: 8.8306 Explore P: 0.1959
# Episode: 388 Total reward: 77.0 Training loss: 6.2742 Explore P: 0.1954
# Episode: 389 Total reward: 87.0 Training loss: 12.6866 Explore P: 0.1952
# Episode: 390 Total reward: 78.0 Training loss: 12.5812 Explore P: 0.1947
# Model Saved
# Episode: 391 Total reward: 40.0 Training loss: 8.7626 Explore P: 0.1938
# Episode: 392 Total reward: 59.0 Training loss: 11.3794 Explore P: 0.1931
# Episode: 393 Total reward: 59.0 Training loss: 14.4731 Explore P: 0.1924
# Episode: 394 Total reward: 73.0 Training loss: 8.0224 Explore P: 0.1920
# Episode: 395 Total reward: 95.0 Training loss: 10.5302 Explore P: 0.1919
# Model Saved
# Episode: 396 Total reward: 57.0 Training loss: 7.5527 Explore P: 0.1913
# Episode: 397 Total reward: 68.0 Training loss: 7.9798 Explore P: 0.1908
# Episode: 398 Total reward: 71.0 Training loss: 10.6014 Explore P: 0.1903
# Episode: 399 Total reward: 61.0 Training loss: 5.9495 Explore P: 0.1897
# Episode: 400 Total reward: 88.0 Training loss: 7.7696 Explore P: 0.1895
# Model Saved
# Episode: 401 Total reward: 19.0 Training loss: 7.7122 Explore P: 0.1883
# Episode: 402 Total reward: 8.0 Training loss: 13.1604 Explore P: 0.1870
# Episode: 403 Total reward: 76.0 Training loss: 5.5728 Explore P: 0.1866
# Episode: 404 Total reward: 83.0 Training loss: 6.8698 Explore P: 0.1863
# Model Saved
# Episode: 406 Total reward: 77.0 Training loss: 8.5871 Explore P: 0.1841
# Episode: 407 Total reward: 86.0 Training loss: 14.9290 Explore P: 0.1839
# Episode: 408 Total reward: 51.0 Training loss: 10.0897 Explore P: 0.1832
# Episode: 409 Total reward: 95.0 Training loss: 10.9272 Explore P: 0.1831
# Episode: 410 Total reward: 78.0 Training loss: 13.0187 Explore P: 0.1827
# Model Saved
# Episode: 412 Total reward: 95.0 Training loss: 10.8947 Explore P: 0.1809
# Episode: 413 Total reward: 72.0 Training loss: 7.3012 Explore P: 0.1804
# Episode: 414 Total reward: 59.0 Training loss: 8.5685 Explore P: 0.1798
# Episode: 415 Total reward: 10.0 Training loss: 5.4742 Explore P: 0.1785
# Model Saved
# Episode: 416 Total reward: 71.0 Training loss: 3.2320 Explore P: 0.1781
# Episode: 417 Total reward: 95.0 Training loss: 29.3025 Explore P: 0.1780
# Episode: 418 Total reward: 36.0 Training loss: 7.0853 Explore P: 0.1771
# Episode: 419 Total reward: 71.0 Training loss: 11.5913 Explore P: 0.1767
# Episode: 420 Total reward: 95.0 Training loss: 5.1014 Explore P: 0.1766
# Model Saved
# Episode: 421 Total reward: 64.0 Training loss: 5.8257 Explore P: 0.1760
# Episode: 422 Total reward: 38.0 Training loss: 4.8999 Explore P: 0.1752
# Episode: 423 Total reward: 82.0 Training loss: 5.8191 Explore P: 0.1748
# Episode: 424 Total reward: 59.0 Training loss: 5.8373 Explore P: 0.1742
# Episode: 425 Total reward: 83.0 Training loss: 5.7389 Explore P: 0.1739
# Model Saved
# Episode: 426 Total reward: 74.0 Training loss: 8.5910 Explore P: 0.1736
# Episode: 427 Total reward: 82.0 Training loss: 11.4571 Explore P: 0.1733
# Episode: 428 Total reward: 53.0 Training loss: 6.4878 Explore P: 0.1727
# Episode: 429 Total reward: 73.0 Training loss: 4.4497 Explore P: 0.1723
# Episode: 430 Total reward: 87.0 Training loss: 5.4515 Explore P: 0.1721
# Model Saved
# Episode: 431 Total reward: 94.0 Training loss: 7.9229 Explore P: 0.1719
# Episode: 432 Total reward: 89.0 Training loss: 9.6513 Explore P: 0.1717
# Episode: 433 Total reward: 95.0 Training loss: 7.5365 Explore P: 0.1716
# Episode: 434 Total reward: 23.0 Training loss: 4.7957 Explore P: 0.1706
# Episode: 435 Total reward: 86.0 Training loss: 10.4622 Explore P: 0.1704
# Model Saved
# Episode: 436 Total reward: 74.0 Training loss: 4.8566 Explore P: 0.1700
# Episode: 437 Total reward: 78.0 Training loss: 6.4711 Explore P: 0.1697
# Episode: 438 Total reward: 68.0 Training loss: 10.1130 Explore P: 0.1692
# Episode: 439 Total reward: 63.0 Training loss: 6.0817 Explore P: 0.1687
# Episode: 440 Total reward: 49.0 Training loss: 5.9166 Explore P: 0.1680
# Model Saved
# Episode: 441 Total reward: 67.0 Training loss: 5.6265 Explore P: 0.1676
# Episode: 442 Total reward: 27.0 Training loss: 12.8690 Explore P: 0.1666
# Episode: 443 Total reward: 90.0 Training loss: 6.3225 Explore P: 0.1664
# Episode: 444 Total reward: 68.0 Training loss: 8.1978 Explore P: 0.1660
# Episode: 445 Total reward: 71.0 Training loss: 9.3334 Explore P: 0.1656
# Model Saved
# Episode: 446 Total reward: 57.0 Training loss: 7.6910 Explore P: 0.1650
# Episode: 447 Total reward: 86.0 Training loss: 7.7963 Explore P: 0.1647
# Episode: 448 Total reward: 95.0 Training loss: 10.1053 Explore P: 0.1646
# Episode: 449 Total reward: 73.0 Training loss: 7.3981 Explore P: 0.1642
# Episode: 450 Total reward: 57.0 Training loss: 4.4033 Explore P: 0.1636
# Model Saved
# Episode: 451 Total reward: 75.0 Training loss: 5.2146 Explore P: 0.1632
# Episode: 452 Total reward: 95.0 Training loss: 5.5955 Explore P: 0.1631
# Episode: 453 Total reward: 61.0 Training loss: 11.4151 Explore P: 0.1626
# Episode: 454 Total reward: 78.0 Training loss: 7.4977 Explore P: 0.1622
# Episode: 455 Total reward: 63.0 Training loss: 8.0178 Explore P: 0.1617
# Model Saved
# Episode: 456 Total reward: 48.0 Training loss: 5.3117 Explore P: 0.1611
# Episode: 457 Total reward: 42.0 Training loss: 8.1183 Explore P: 0.1603
# Episode: 458 Total reward: 88.0 Training loss: 15.2514 Explore P: 0.1601
# Episode: 459 Total reward: 90.0 Training loss: 9.9599 Explore P: 0.1600
# Episode: 460 Total reward: 36.0 Training loss: 4.5314 Explore P: 0.1592
# Model Saved
# Episode: 461 Total reward: 62.0 Training loss: 10.0182 Explore P: 0.1587
# Episode: 462 Total reward: 95.0 Training loss: 18.9448 Explore P: 0.1586
# Episode: 463 Total reward: 64.0 Training loss: 5.1572 Explore P: 0.1581
# Episode: 464 Total reward: 95.0 Training loss: 8.6543 Explore P: 0.1580
# Episode: 465 Total reward: 52.0 Training loss: 6.4748 Explore P: 0.1573
# Model Saved
# Episode: 466 Total reward: 55.0 Training loss: 4.2257 Explore P: 0.1568
# Episode: 467 Total reward: 95.0 Training loss: 3.6769 Explore P: 0.1567
# Episode: 468 Total reward: 65.0 Training loss: 9.1739 Explore P: 0.1563
# Episode: 469 Total reward: 78.0 Training loss: 8.1805 Explore P: 0.1559
# Episode: 470 Total reward: 59.0 Training loss: 6.2198 Explore P: 0.1554
# Model Saved
# Episode: 471 Total reward: 93.0 Training loss: 4.9516 Explore P: 0.1553
# Episode: 472 Total reward: 78.0 Training loss: 7.1612 Explore P: 0.1550
# Episode: 473 Total reward: 65.0 Training loss: 4.2277 Explore P: 0.1545
# Episode: 474 Total reward: 40.0 Training loss: 4.2799 Explore P: 0.1538
# Episode: 475 Total reward: 95.0 Training loss: 7.2762 Explore P: 0.1537
# Model Saved
# Episode: 476 Total reward: 82.0 Training loss: 7.6366 Explore P: 0.1534
# Episode: 477 Total reward: 91.0 Training loss: 8.5657 Explore P: 0.1533
# Episode: 478 Total reward: 61.0 Training loss: 11.2142 Explore P: 0.1528
# Episode: 479 Total reward: 63.0 Training loss: 9.6816 Explore P: 0.1523
# Episode: 480 Total reward: 78.0 Training loss: 9.1009 Explore P: 0.1520
# Model Saved
# Episode: 481 Total reward: 59.0 Training loss: 8.2821 Explore P: 0.1514
# Episode: 482 Total reward: 49.0 Training loss: 16.2531 Explore P: 0.1509
# Episode: 483 Total reward: 89.0 Training loss: 17.7018 Explore P: 0.1507
# Episode: 485 Total reward: 86.0 Training loss: 6.6781 Explore P: 0.1491
# Model Saved
# Episode: 486 Total reward: 69.0 Training loss: 8.7992 Explore P: 0.1487
# Episode: 487 Total reward: 91.0 Training loss: 7.2378 Explore P: 0.1486
# Episode: 488 Total reward: 62.0 Training loss: 13.5358 Explore P: 0.1481
# Episode: 489 Total reward: 76.0 Training loss: 5.6572 Explore P: 0.1477
# Episode: 490 Total reward: 66.0 Training loss: 3.0384 Explore P: 0.1473
# Model Saved
# Episode: 491 Total reward: 95.0 Training loss: 5.9354 Explore P: 0.1473
# Episode: 492 Total reward: 66.0 Training loss: 10.0826 Explore P: 0.1468
# Episode: 493 Total reward: 85.0 Training loss: 6.7166 Explore P: 0.1466
# Episode: 494 Total reward: 67.0 Training loss: 4.1692 Explore P: 0.1462
# Episode: 495 Total reward: 72.0 Training loss: 7.9094 Explore P: 0.1459
# Model Saved
# Episode: 496 Total reward: 90.0 Training loss: 8.8768 Explore P: 0.1457
# Episode: 497 Total reward: 56.0 Training loss: 12.2237 Explore P: 0.1452
# Episode: 498 Total reward: 54.0 Training loss: 5.0786 Explore P: 0.1446
# Episode: 499 Total reward: 69.0 Training loss: 5.5970 Explore P: 0.1442

# %% [markdown]
# ## Step 9: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
with tf.compat.v1.Session() as sess:

    game, possible_actions = create_environment()

    totalScore = 0

    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    for i in range(100):

        done = False

        game.new_episode()

        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
            # Take the biggest Q value (= the best action)
            Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

            # Take the biggest Q value (= the best action)
            choice = np.argmax(Qs)
            action = possible_actions[int(choice)]

            game.make_action(action)
            done = game.is_episode_finished()
            score = game.get_total_reward()

            if done:
                break

            else:
                print("else")
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state

        score = game.get_total_reward()
        print("Score: ", score)
    game.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  80.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  56.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  37.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  58.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  87.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  79.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  36.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  78.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# Score:  94.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  85.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  38.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  72.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  72.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  40.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  73.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  72.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  56.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  58.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  90.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  91.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# Score:  94.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  84.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  87.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  84.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  51.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  57.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  56.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  85.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  80.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  76.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  78.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  69.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  52.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  2.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  86.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  86.0
# else
# else
# else
# else
# else
# else
# else
# Score:  93.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  -6.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  76.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  72.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  57.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# Score:  94.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  80.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  58.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  -16.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  63.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  88.0
# else
# else
# else
# else
# else
# else
# Score:  94.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  78.0
# else
# else
# else
# else
# else
# Score:  95.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  87.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# Score:  93.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  57.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  57.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  59.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  62.0
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  82.0
